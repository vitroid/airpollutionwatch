# %%
import requests

response = requests.get(
    "https://air.taiki.pref.chiba.lg.jp/hourreport/?day=2024年08月08日&hour=23",
)
# これがないと文字化けする
response.encoding = response.apparent_encoding

# %%
from IPython.display import HTML

HTML(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="ja">
# <head>
# <meta charset="utf-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0,user-scalable=no">
# <meta name="format-detection" content="telephone=no">
# <title>リアルタイム時報 | ちばの大気環境 | 千葉県</title>
# <script src="../js/jquery.min.js"></script>
# <script src="../js/fixHeader.js"></script>
# <script type="text/javascript" src="https://code.jquery.com/ui/1.10.3/jquery-ui.min.js"></script>
# <script type="text/javascript" src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.10.3/i18n/jquery-ui-i18n.min.js"></script>
# <link rel="stylesheet" href="https://ajax.googleapis.com/ajax/libs/jqueryui/1/themes/redmond/jquery-ui.css">
# <script src="../js/common.js"></script>
# <link href="https://fonts.googleapis.com/css?family=M+PLUS+Rounded+1c" rel="stylesheet">
# <link rel="stylesheet" href="./css/style.css">
# </head>
# <body>
#
# <header id="globalHeader">
# ...

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="ja">
# <head>
# <meta charset="utf-8">
# <meta name="viewport" content="width=device-width,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0,user-scalable=no">
# <meta name="format-detection" content="telephone=no">
# <title>リアルタイム時報 | ちばの大気環境 | 千葉県</title>
# <script src="../js/jquery.min.js"></script>
# <script src="../js/fixHeader.js"></script>
# <script type="text/javascript" src="https://code.jquery.com/ui/1.10.3/jquery-ui.min.js"></script>
# <script type="text/javascript" src="https://ajax.googleapis.com/ajax/libs/jqueryui/1.10.3/i18n/jquery-ui-i18n.min.js"></script>
# <link rel="stylesheet" href="https://ajax.googleapis.com/ajax/libs/jqueryui/1/themes/redmond/jquery-ui.css">
# <script src="../js/common.js"></script>
# <link href="https://fonts.googleapis.com/css?family=M+PLUS+Rounded+1c" rel="stylesheet">
# <link rel="stylesheet" href="./css/style.css">
# </head>
# <body>
#
# <header id="globalHeader">
# ...

# %%
import pandas as pd
import io

df = pd.read_html(io.StringIO(response.text))
df
# Out:
# [        地域     測定局 種別 SO2 ppm NO ppm NO2 ppm NOX ppm OX ppm SPM mg/m3  \
#  0       野田   野田桐ケ作  般    ----  0.001   0.004   0.005  0.007      ----
#  1       野田   野田市野田  般   0.000  0.000   0.005   0.005  0.007     0.018
#  2       野田    野田宮崎  自    ----  0.006   0.007   0.013   ----     0.012
#  3       東葛   流山平和台  般   0.000  0.000   0.005   0.005  0.012     0.002
#  4       東葛    柏永楽台  般   0.000  0.000   0.004   0.004  0.010     0.009
#  ..     ...     ... ..     ...    ...     ...     ...    ...       ...
#  102  長生・夷隅    茂原高師  般    ----  0.001   0.003   0.004  0.010     0.009
#  103  長生・夷隅   一宮東浪見  般   0.000  0.000   0.001   0.001  0.017     0.007
#  104  長生・夷隅    勝浦植野  般    ----    NaN     NaN     NaN  0.004     0.007
#  105    南房総   館山亀ケ原  般   0.000  0.001   0.002   0.003  0.006     0.010
#  106    南房総  鋸南下佐久間  般    ----   ----    ----    ----  0.005     0.013
#
#      PM2.5 ug/m3 NMHC ppmC CH4 ppmC THC ppmC CO ppm WD 方位 WV m/s TEMP ℃ HUM %
# ...

# %% [markdown]
# # パッケージ化

# %%
from airpollution import chiba
import pandas as pd

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

print(chiba.retrieve("2024-08-08T10:00+09:00"))
# Out:
#           SO2    NO   NO2   NOX    OX   SPM  PM25  NMHC    CH4    THC   CO  \
# station
# 12303010  NaN   2.0   6.0   8.0  21.0   NaN  10.0   NaN    NaN    NaN  NaN
# 12208010  0.0   3.0   6.0   9.0  21.0  30.0  11.0   9.0  202.0  211.0  NaN
# 12208510  NaN  14.0  13.0  27.0   NaN  21.0   7.0   9.0  200.0  209.0  2.0
# 12220010  0.0   5.0   8.0  13.0  21.0  19.0   5.0  29.0  212.0  241.0  NaN
# 12217020  0.0   1.0   4.0   5.0  21.0  14.0   7.0  11.0  207.0  218.0  NaN
# 12217030  0.0   5.0   3.0   8.0  22.0  12.0  13.0   NaN    NaN    NaN  NaN
# 12217510  NaN   7.0   9.0  16.0   NaN   NaN   NaN  14.0  204.0  218.0  2.0
# 12217520  NaN   3.0   8.0  11.0   NaN  16.0   NaN   NaN    NaN    NaN  NaN
# 12305510  NaN  11.0  10.0  21.0   NaN  11.0   8.0   NaN    NaN    NaN  2.0
# 12207010  1.0   2.0   6.0   8.0  15.0  14.0   6.0  21.0  201.0  222.0  NaN
# 12207020  0.0   1.0   4.0   5.0  23.0  14.0   NaN   6.0  203.0  209.0  NaN
# ...
