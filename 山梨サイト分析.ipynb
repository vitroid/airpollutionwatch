# %%
import json

! wget https://taiki.pref.yamanashi.jp/data/202408/2024080815.json

with open("2024080815.json") as f:
    table = json.load(f)
table
# Out:
# --2024-08-08 13:24:28--  https://taiki.pref.yamanashi.jp/data/202408/2024080815.json
# Resolving taiki.pref.yamanashi.jp (taiki.pref.yamanashi.jp)... 103.2.2.190
# Connecting to taiki.pref.yamanashi.jp (taiki.pref.yamanashi.jp)|103.2.2.190|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1862 (1.8K) [application/json]
# Saving to: ‘2024080815.json’
#
# 2024080815.json     100%[===================>]   1.82K  --.-KB/s    in 0s
#
# 2024-08-08 13:24:28 (23.9 MB/s) - ‘2024080815.json’ saved [1862/1862]
# {'0103': {'001': '0.001',
#   '002': '0.000',
#   '003': '0.003',
#   '004': '0.003',
#   '006': '0.062',
#   '007': '0.04',
#   '008': '1.98',
#   '009': '2.02',
#   '010': '0.023',
#   '012': '20',
#   '026': '62',
#   '050': '2',
#   '051': '3.8',
#   '995': '308',
#   '996': '0.043'},
#  '0104': {'002': '0.001',
#   '003': '0.004',
#   '004': '0.005',
#   '006': '0.068',
#   '007': '0.13',
#   '008': '1.92',
#   '009': '2.05',
#   '010': '0.018',
#   '012': '14',
#   '026': '72',
#   '050': '6',
#   '051': '4.2',
#   '995': '295',
#   '996': '0.042'},
#  '0105': {'002': '0.001',
#   '003': '0.002',
#   '004': '0.003',
#   '006': '0.053',
#   '012': '9',
#   '026': '56',
#   '050': '13',
#   '051': '0.8',
#   '995': '327'},
#  '0106': {'001': '0.001',
#   '002': '0.001',
#   '003': '0.005',
#   '004': '0.006',
#   '006': '0.056',
#   '010': '0.028',
#   '012': '17',
#   '026': '57',
#   '050': '2',
#   '051': '2.9',
#   '995': '292',
#   '996': '0.043'},
#  '0108': {'002': '0.001',
#   '003': '0.002',
#   '004': '0.003',
#   '006': '0.057',
#   '010': '0.022',
#   '012': '13',
#   '026': '59',
#   '050': '10',
#   '051': '3.2',
#   '995': '278',
#   '996': '0.052'},
#  '0109': {'006': '0.055',
#   '026': '57',
#   '050': '2',
#   '051': '2.1',
#   '995': '280',
#   '996': '0.041'},
#  '0110': {'002': '0.001',
#   '003': '0.003',
#   '004': '0.004',
#   '006': '0.059',
#   '010': '0.017',
#   '012': '30',
#   '026': '59',
#   '050': '12',
#   '051': '2.4',
#   '995': '274',
#   '996': '0.049'},
#  '0111': {'002': '0.001',
#   '003': '0.006',
#   '004': '0.007',
#   '006': '0.057',
#   '010': '0.015',
#   '012': '9',
#   '026': '59',
#   '050': '7',
#   '051': '1.6',
#   '995': '312',
#   '996': '0.048'},
#  '0112': {'002': '0.000',
#   '003': '0.001',
#   '004': '0.001',
#   '006': '0.057',
#   '010': '0.010',
#   '012': '9',
#   '026': '58',
#   '050': '11',
#   '051': '2.1',
#   '995': '257',
#   '996': '0.046'},
#  '0113': {'001': '0.001',
#   '002': '0.000',
#   '003': '0.002',
#   '004': '0.002',
#   '006': '0.066',
#   '007': '0.24',
#   '008': '1.96',
#   '009': '2.20',
#   '010': '0.019',
#   '012': '39',
#   '026': '65',
#   '050': '10',
#   '051': '0.6',
#   '996': '0.059'},
#  '0201': {'002': '0.001',
#   '003': '0.007',
#   '004': '0.008',
#   '005': '0.2',
#   '010': '0.013',
#   '012': '9',
#   '050': '10',
#   '051': '0.7'},
#  '0204': {'005': '0.3',
#   '010': '0.015',
#   '012': '45',
#   '050': '12',
#   '051': '1.0'},
#  '0304': {'002': '0.000',
#   '003': '0.002',
#   '004': '0.002',
#   '006': '0.057',
#   '010': '0.003',
#   '026': '57',
#   '050': '9',
#   '051': '5.0',
#   '995': '259',
#   '996': '0.047'}}

# %%
! wget https://taiki.pref.yamanashi.jp/data/V501Station.json

with open("V501Station.json") as f:
    stations = json.load(f)
stations
# Out:
# --2024-08-08 13:25:27--  https://taiki.pref.yamanashi.jp/data/V501Station.json
# Resolving taiki.pref.yamanashi.jp (taiki.pref.yamanashi.jp)... 103.2.2.190
# Connecting to taiki.pref.yamanashi.jp (taiki.pref.yamanashi.jp)|103.2.2.190|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6181 (6.0K) [application/json]
# Saving to: ‘V501Station.json’
#
# V501Station.json    100%[===================>]   6.04K  --.-KB/s    in 0s
#
# 2024-08-08 13:25:27 (86.2 MB/s) - ‘V501Station.json’ saved [6181/6181]
# {'0102': {'code': '0102',
#   'name': '甲府富士見',
#   'wno': '11',
#   'wx': None,
#   'wy': None,
#   'wr': None,
#   'sd': 19900401,
#   'ed': 20230319,
#   'od': 10,
#   'cate': '一般',
#   'div': '01',
#   'north': None,
#   'east': None,
#   'color': '000000',
#   'mapInfoOffX': '0',
#   'mapInfoOffY': '0',
#   'mapgInfoOffX': '0',
#   'mapgInfoOffY': '0',
#   'addressNm': '富士見1-7-31',
#   'introUrlWeb': None,
#   'webAreaCd': '001',
#   'manageMent': '甲府市'},
#  '0113': {'code': '0113',
#   'name': '甲府穴切',
#   'wno': '11',
#   'wx': None,
#   'wy': None,
#   'wr': None,
#   'sd': 20230401,
#   'ed': 99991231,
#   'od': 10,
#   'cate': '一般',
#   'div': '01',
#   'north': 48.0,
#   'east': 35.0,
#   'color': '000000',
#   'mapInfoOffX': '0',
#   'mapInfoOffY': '0',
#   'mapgInfoOffX': '0',
#   'mapgInfoOffY': '0',
#   'addressNm': '宝2-8-19',
#   'introUrlWeb': None,
#   'webAreaCd': '001',
#   'manageMent': '甲府市'},
#  '0103': {'code': '0103',
#   'name': '大月',
#   'wno': '01',
#   'wx': None,
#   'wy': None,
#   'wr': None,
#   'sd': 19900401,
#   'ed': 99991231,
#   'od': 20,
#   'cate': '一般',
#   'div': '01',
#   'north': None,
#   'east': None,
#   'color': 'FF0000',
#   'mapInfoOffX': '0',
#   'mapInfoOffY': '0',
#   'mapgInfoOffX': '0',
#   'mapgInfoOffY': '0',
#   'addressNm': '花咲1608-3',
#   'introUrlWeb': None,
#   'webAreaCd': '001',
#   'manageMent': '山梨県'},
#  '0104': {'code': '0104',
#   'name': '上野原',
#   'wno': '02',
#   'wx': None,
#   'wy': None,
#   'wr': None,
#   'sd': 19900401,
#   'ed': 99991231,
#   'od': 30,
#   'cate': '一般',
#   'div': '01',
#   'north': None,
#   'east': None,
#   'color': '00ffff',
#   'mapInfoOffX': '0',
#   'mapInfoOffY': '0',
#   'mapgInfoOffX': '0',
#   'mapgInfoOffY': '0',
#   'addressNm': '上野原3832',
#   'introUrlWeb': None,
#   'webAreaCd': '001',
#   'manageMent': '山梨県'},
#  '0109': {'code': '0109',
#   'name': '都留',
#   'wno': '07',
#   'wx': None,
#   'wy': None,
#   'wr': None,
#   'sd': 19900401,
#   'ed': 99991231,
#   'od': 40,
#   'cate': '一般',
#   'div': '01',
#   'north': None,
#   'east': None,
#   'color': '808000',
#   'mapInfoOffX': '0',
#   'mapInfoOffY': '0',
#   'mapgInfoOffX': '0',
#   'mapgInfoOffY': '0',
#   'addressNm': '田原二丁目1204',
#   'introUrlWeb': None,
#   'webAreaCd': '001',
#   'manageMent': '山梨県'},
#  '0106': {'code': '0106',
#   'name': '吉田',
#   'wno': '04',
#   'wx': None,
#   'wy': None,
#   'wr': None,
#   'sd': 19900401,
#   'ed': 99991231,
#   'od': 50,
#   'cate': '一般',
#   'div': '01',
#   'north': None,
#   'east': None,
#   'color': '0000ff',
#   'mapInfoOffX': '0',
#   'mapInfoOffY': '0',
#   'mapgInfoOffX': '0',
#   'mapgInfoOffY': '0',
#   'addressNm': '上吉田1-2-5',
#   'introUrlWeb': None,
#   'webAreaCd': '001',
#   'manageMent': '山梨県'},
#  '0112': {'code': '0112',
#   'name': '南部',
#   'wno': '05',
#   'wx': None,
#   'wy': None,
#   'wr': None,
#   'sd': 20020401,
#   'ed': 99991231,
#   'od': 60,
#   'cate': '一般',
#   'div': '01',
#   'north': None,
#   'east': None,
#   'color': 'FFCC33',
#   'mapInfoOffX': '0',
#   'mapInfoOffY': '0',
#   'mapgInfoOffX': '0',
#   'mapgInfoOffY': '0',
#   'addressNm': '南部9103-3',
#   'introUrlWeb': None,
#   'webAreaCd': '001',
#   'manageMent': '山梨県'},
#  '0108': {'code': '0108',
#   'name': '南アルプス',
#   'wno': '06',
#   'wx': None,
#   'wy': None,
#   'wr': None,
#   'sd': 19900401,
#   'ed': 99991231,
#   'od': 70,
#   'cate': '一般',
#   'div': '01',
#   'north': None,
#   'east': None,
#   'color': '800000',
#   'mapInfoOffX': '0',
#   'mapInfoOffY': '0',
#   'mapgInfoOffX': '0',
#   'mapgInfoOffY': '0',
#   'addressNm': '鏡中條1642-2',
#   'introUrlWeb': None,
#   'webAreaCd': '001',
#   'manageMent': '山梨県'},
#  '0111': {'code': '0111',
#   'name': '韮崎',
#   'wno': '09',
#   'wx': None,
#   'wy': None,
#   'wr': None,
#   'sd': 19900401,
#   'ed': 99991231,
#   'od': 80,
#   'cate': '一般',
#   'div': '01',
#   'north': None,
#   'east': None,
#   'color': 'ff5f17',
#   'mapInfoOffX': '0',
#   'mapInfoOffY': '0',
#   'mapgInfoOffX': '0',
#   'mapgInfoOffY': '0',
#   'addressNm': '本町4-2-4',
#   'introUrlWeb': None,
#   'webAreaCd': '001',
#   'manageMent': '山梨県'},
#  '0105': {'code': '0105',
#   'name': '笛吹',
#   'wno': '03',
#   'wx': None,
#   'wy': None,
#   'wr': None,
#   'sd': 19900401,
#   'ed': 99991231,
#   'od': 90,
#   'cate': '一般',
#   'div': '01',
#   'north': None,
#   'east': None,
#   'color': '888888',
#   'mapInfoOffX': '0',
#   'mapInfoOffY': '0',
#   'mapgInfoOffX': '0',
#   'mapgInfoOffY': '0',
#   'addressNm': '石和町上平井1047-1',
#   'introUrlWeb': None,
#   'webAreaCd': '001',
#   'manageMent': '山梨県'},
#  '0110': {'code': '0110',
#   'name': '東山梨',
#   'wno': '08',
#   'wx': None,
#   'wy': None,
#   'wr': None,
#   'sd': 19900401,
#   'ed': 99991231,
#   'od': 100,
#   'cate': '一般',
#   'div': '01',
#   'north': None,
#   'east': None,
#   'color': 'ff99ff',
#   'mapInfoOffX': '0',
#   'mapInfoOffY': '0',
#   'mapgInfoOffX': '0',
#   'mapgInfoOffY': '0',
#   'addressNm': '塩山上塩後1239-1',
#   'introUrlWeb': None,
#   'webAreaCd': '001',
#   'manageMent': '山梨県'},
#  '0201': {'code': '0201',
#   'name': '甲府市役所自排',
#   'wno': '12',
#   'wx': None,
#   'wy': None,
#   'wr': None,
#   'sd': 19900401,
#   'ed': 99991231,
#   'od': 110,
#   'cate': '自排',
#   'div': '02',
#   'north': None,
#   'east': None,
#   'color': '008000',
#   'mapInfoOffX': '0',
#   'mapInfoOffY': '0',
#   'mapgInfoOffX': '0',
#   'mapgInfoOffY': '0',
#   'addressNm': '丸の内1-18-1',
#   'introUrlWeb': None,
#   'webAreaCd': '001',
#   'manageMent': '甲府市'},
#  '0204': {'code': '0204',
#   'name': '国母自排',
#   'wno': '13',
#   'wx': None,
#   'wy': None,
#   'wr': None,
#   'sd': 19900401,
#   'ed': 99991231,
#   'od': 120,
#   'cate': '自排',
#   'div': '02',
#   'north': None,
#   'east': None,
#   'color': '00ff00',
#   'mapInfoOffX': '0',
#   'mapInfoOffY': '0',
#   'mapgInfoOffX': '0',
#   'mapgInfoOffY': '0',
#   'addressNm': '国母6-5-1',
#   'introUrlWeb': None,
#   'webAreaCd': '001',
#   'manageMent': '甲府市'},
#  '0301': {'code': '0301',
#   'name': '移動局_富士河口湖',
#   'wno': '16',
#   'wx': None,
#   'wy': None,
#   'wr': None,
#   'sd': 20210322,
#   'ed': 20211028,
#   'od': 301,
#   'cate': '一般',
#   'div': '01',
#   'north': None,
#   'east': None,
#   'color': '800080',
#   'mapInfoOffX': '0',
#   'mapInfoOffY': '0',
#   'mapgInfoOffX': '0',
#   'mapgInfoOffY': '0',
#   'addressNm': '南都留郡富士河口湖町船津１７００',
#   'introUrlWeb': None,
#   'webAreaCd': '001',
#   'manageMent': '山梨県'},
#  '0302': {'code': '0302',
#   'name': '移動局_市川三郷',
#   'wno': '16',
#   'wx': None,
#   'wy': None,
#   'wr': None,
#   'sd': 20211101,
#   'ed': 20221122,
#   'od': 301,
#   'cate': '一般',
#   'div': '01',
#   'north': None,
#   'east': None,
#   'color': '800080',
#   'mapInfoOffX': '0',
#   'mapInfoOffY': '0',
#   'mapgInfoOffX': '0',
#   'mapgInfoOffY': '0',
#   'addressNm': '西八代郡市川三郷町市川大門3079',
#   'introUrlWeb': None,
#   'webAreaCd': '001',
#   'manageMent': '山梨県'},
#  '0303': {'code': '0303',
#   'name': '移動局_富士川',
#   'wno': '16',
#   'wx': None,
#   'wy': None,
#   'wr': None,
#   'sd': 20221129,
#   'ed': 20230927,
#   'od': 301,
#   'cate': '一般',
#   'div': '01',
#   'north': None,
#   'east': None,
#   'color': '800080',
#   'mapInfoOffX': '0',
#   'mapInfoOffY': '0',
#   'mapgInfoOffX': '0',
#   'mapgInfoOffY': '0',
#   'addressNm': '南巨摩郡富士川町鰍沢771－2',
#   'introUrlWeb': None,
#   'webAreaCd': '001',
#   'manageMent': '山梨県'},
#  '0304': {'code': '0304',
#   'name': '移動局_身延',
#   'wno': '16',
#   'wx': None,
#   'wy': None,
#   'wr': None,
#   'sd': 20231107,
#   'ed': 99991231,
#   'od': 301,
#   'cate': '一般',
#   'div': '01',
#   'north': None,
#   'east': None,
#   'color': '800080',
#   'mapInfoOffX': '0',
#   'mapInfoOffY': '0',
#   'mapgInfoOffX': '0',
#   'mapgInfoOffY': '0',
#   'addressNm': '南巨摩郡身延町大野1131-1',
#   'introUrlWeb': None,
#   'webAreaCd': '001',
#   'manageMent': '山梨県'}}

# %%
! wget https://taiki.pref.yamanashi.jp/data/V503StationItem.json

with open("V503StationItem.json") as f:
    station_items = json.load(f)
station_items
# Out:
# --2024-08-08 13:26:20--  https://taiki.pref.yamanashi.jp/data/V503StationItem.json
# Resolving taiki.pref.yamanashi.jp (taiki.pref.yamanashi.jp)... 103.2.2.190
# Connecting to taiki.pref.yamanashi.jp (taiki.pref.yamanashi.jp)|103.2.2.190|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 13486 (13K) [application/json]
# Saving to: ‘V503StationItem.json’
#
# V503StationItem.jso 100%[===================>]  13.17K  --.-KB/s    in 0s
#
# 2024-08-08 13:26:21 (141 MB/s) - ‘V503StationItem.json’ saved [13486/13486]
# {'0101': {'001': {'SD': '19900401', 'ED': '19930331', 'VFlg': '1'},
#   '005': {'SD': '19900401', 'ED': '19930331', 'VFlg': '1'},
#   '010': {'SD': '19900401', 'ED': '19930331', 'VFlg': '1'}},
#  '0102': {'001': {'SD': '19900401', 'ED': '20230319', 'VFlg': '1'},
#   '002': {'SD': '19900401', 'ED': '20230319', 'VFlg': '1'},
#   '003': {'SD': '19900401', 'ED': '20230319', 'VFlg': '1'},
#   '004': {'SD': '19900401', 'ED': '20230319', 'VFlg': '1'},
#   '005': {'SD': '19900401', 'ED': '20080603', 'VFlg': '0'},
#   '006': {'SD': '19900401', 'ED': '20230319', 'VFlg': '1'},
#   '007': {'SD': '19900401', 'ED': '20230319', 'VFlg': '1'},
#   '008': {'SD': '19900401', 'ED': '20230319', 'VFlg': '1'},
#   '009': {'SD': '19900401', 'ED': '20230319', 'VFlg': '1'},
#   '010': {'SD': '19900401', 'ED': '20230319', 'VFlg': '1'},
#   '012': {'SD': '20100401', 'ED': '20230319', 'VFlg': '1'},
#   '026': {'SD': '19900401', 'ED': '20230319', 'VFlg': '1'},
#   '050': {'SD': '19900401', 'ED': '20230319', 'VFlg': '1'},
#   '051': {'SD': '19900401', 'ED': '20230319', 'VFlg': '1'},
#   '996': {'SD': '19900401', 'ED': '20230319', 'VFlg': '1'}},
#  '0103': {'001': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '002': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '003': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '004': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '005': {'SD': '19900401', 'ED': '19980331', 'VFlg': '1'},
#   '006': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '007': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '008': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '009': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '010': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '012': {'SD': '20110324', 'ED': '99991231', 'VFlg': '1'},
#   '026': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '050': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '051': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '995': {'SD': '20181201', 'ED': '99991231', 'VFlg': '1'},
#   '996': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'}},
#  '0104': {'002': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '003': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '004': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '006': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '007': {'SD': '20221110', 'ED': '99991231', 'VFlg': '1'},
#   '008': {'SD': '20221110', 'ED': '99991231', 'VFlg': '1'},
#   '009': {'SD': '20221110', 'ED': '99991231', 'VFlg': '1'},
#   '010': {'SD': '20040609', 'ED': '99991231', 'VFlg': '1'},
#   '011': {'SD': '20120530', 'ED': '20181215', 'VFlg': '1'},
#   '012': {'SD': '20230303', 'ED': '99991231', 'VFlg': '1'},
#   '026': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '050': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '051': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '052': {'SD': '20120528', 'ED': '20120529', 'VFlg': '1'},
#   '995': {'SD': '20181201', 'ED': '99991231', 'VFlg': '1'},
#   '996': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'}},
#  '0105': {'002': {'SD': '19901101', 'ED': '99991231', 'VFlg': '1'},
#   '003': {'SD': '19901101', 'ED': '99991231', 'VFlg': '1'},
#   '004': {'SD': '19901101', 'ED': '99991231', 'VFlg': '1'},
#   '005': {'SD': '19901101', 'ED': '19980331', 'VFlg': '1'},
#   '006': {'SD': '19901101', 'ED': '99991231', 'VFlg': '1'},
#   '010': {'SD': '20020613', 'ED': '20210405', 'VFlg': '1'},
#   '012': {'SD': '20230130', 'ED': '99991231', 'VFlg': '1'},
#   '026': {'SD': '19901101', 'ED': '99991231', 'VFlg': '1'},
#   '050': {'SD': '19901101', 'ED': '99991231', 'VFlg': '1'},
#   '051': {'SD': '19901101', 'ED': '99991231', 'VFlg': '1'},
#   '995': {'SD': '20181201', 'ED': '99991231', 'VFlg': '1'},
#   '996': {'SD': '19901101', 'ED': '99991231', 'VFlg': '1'}},
#  '0106': {'001': {'SD': '20080604', 'ED': '99991231', 'VFlg': '1'},
#   '002': {'SD': '19901101', 'ED': '99991231', 'VFlg': '1'},
#   '003': {'SD': '19901101', 'ED': '99991231', 'VFlg': '1'},
#   '004': {'SD': '19901101', 'ED': '99991231', 'VFlg': '1'},
#   '005': {'SD': '19901101', 'ED': '19980331', 'VFlg': '1'},
#   '006': {'SD': '19901101', 'ED': '99991231', 'VFlg': '1'},
#   '010': {'SD': '20030604', 'ED': '99991231', 'VFlg': '1'},
#   '012': {'SD': '20140717', 'ED': '99991231', 'VFlg': '1'},
#   '026': {'SD': '19901101', 'ED': '99991231', 'VFlg': '1'},
#   '050': {'SD': '19901101', 'ED': '99991231', 'VFlg': '1'},
#   '051': {'SD': '19901101', 'ED': '99991231', 'VFlg': '1'},
#   '995': {'SD': '20181201', 'ED': '99991231', 'VFlg': '1'},
#   '996': {'SD': '19901101', 'ED': '99991231', 'VFlg': '1'}},
#  '0107': {'002': {'SD': '19901101', 'ED': '20020423', 'VFlg': '1'},
#   '003': {'SD': '19901101', 'ED': '20020423', 'VFlg': '1'},
#   '004': {'SD': '19901101', 'ED': '20020423', 'VFlg': '1'},
#   '005': {'SD': '19901101', 'ED': '20020423', 'VFlg': '1'},
#   '006': {'SD': '19901101', 'ED': '20020423', 'VFlg': '1'},
#   '010': {'SD': '19901101', 'ED': '20020423', 'VFlg': '1'},
#   '026': {'SD': '19901101', 'ED': '20020423', 'VFlg': '1'},
#   '050': {'SD': '19901101', 'ED': '20020423', 'VFlg': '1'},
#   '051': {'SD': '19901101', 'ED': '20020423', 'VFlg': '1'},
#   '996': {'SD': '19901101', 'ED': '20020423', 'VFlg': '1'}},
#  '0108': {'002': {'SD': '19930401', 'ED': '99991231', 'VFlg': '1'},
#   '003': {'SD': '19930401', 'ED': '99991231', 'VFlg': '1'},
#   '004': {'SD': '19930401', 'ED': '99991231', 'VFlg': '1'},
#   '005': {'SD': '19930428', 'ED': '19980331', 'VFlg': '1'},
#   '006': {'SD': '19930401', 'ED': '99991231', 'VFlg': '1'},
#   '010': {'SD': '20040604', 'ED': '99991231', 'VFlg': '1'},
#   '012': {'SD': '20210921', 'ED': '99991231', 'VFlg': '1'},
#   '026': {'SD': '19930401', 'ED': '99991231', 'VFlg': '1'},
#   '050': {'SD': '19930401', 'ED': '99991231', 'VFlg': '1'},
#   '051': {'SD': '19930401', 'ED': '99991231', 'VFlg': '1'},
#   '995': {'SD': '20181201', 'ED': '99991231', 'VFlg': '1'},
#   '996': {'SD': '19930401', 'ED': '99991231', 'VFlg': '1'}},
#  '0109': {'002': {'SD': '19931202', 'ED': '99991231', 'VFlg': '1'},
#   '003': {'SD': '19931202', 'ED': '99991231', 'VFlg': '1'},
#   '004': {'SD': '19931202', 'ED': '99991231', 'VFlg': '1'},
#   '005': {'SD': '19931202', 'ED': '19980331', 'VFlg': '1'},
#   '006': {'SD': '19931202', 'ED': '99991231', 'VFlg': '1'},
#   '010': {'SD': '20040604', 'ED': '20210324', 'VFlg': '1'},
#   '026': {'SD': '19931202', 'ED': '99991231', 'VFlg': '1'},
#   '050': {'SD': '19931202', 'ED': '99991231', 'VFlg': '1'},
#   '051': {'SD': '19931202', 'ED': '99991231', 'VFlg': '1'},
#   '995': {'SD': '20181201', 'ED': '99991231', 'VFlg': '1'},
#   '996': {'SD': '19931202', 'ED': '99991231', 'VFlg': '1'}},
#  '0110': {'002': {'SD': '19950218', 'ED': '99991231', 'VFlg': '1'},
#   '003': {'SD': '19950218', 'ED': '99991231', 'VFlg': '1'},
#   '004': {'SD': '19950218', 'ED': '99991231', 'VFlg': '1'},
#   '006': {'SD': '19950218', 'ED': '99991231', 'VFlg': '1'},
#   '010': {'SD': '20030604', 'ED': '99991231', 'VFlg': '1'},
#   '012': {'SD': '20120313', 'ED': '99991231', 'VFlg': '1'},
#   '026': {'SD': '19950218', 'ED': '99991231', 'VFlg': '1'},
#   '050': {'SD': '19950218', 'ED': '99991231', 'VFlg': '1'},
#   '051': {'SD': '19950218', 'ED': '99991231', 'VFlg': '1'},
#   '995': {'SD': '20181201', 'ED': '99991231', 'VFlg': '1'},
#   '996': {'SD': '19950218', 'ED': '99991231', 'VFlg': '1'}},
#  '0111': {'002': {'SD': '19950214', 'ED': '99991231', 'VFlg': '1'},
#   '003': {'SD': '19950214', 'ED': '99991231', 'VFlg': '1'},
#   '004': {'SD': '19950214', 'ED': '99991231', 'VFlg': '1'},
#   '006': {'SD': '19950214', 'ED': '99991231', 'VFlg': '1'},
#   '010': {'SD': '20020613', 'ED': '99991231', 'VFlg': '1'},
#   '012': {'SD': '20210312', 'ED': '99991231', 'VFlg': '1'},
#   '026': {'SD': '19950214', 'ED': '99991231', 'VFlg': '1'},
#   '050': {'SD': '19950214', 'ED': '99991231', 'VFlg': '1'},
#   '051': {'SD': '19950214', 'ED': '99991231', 'VFlg': '1'},
#   '995': {'SD': '20181201', 'ED': '99991231', 'VFlg': '1'},
#   '996': {'SD': '19950214', 'ED': '99991231', 'VFlg': '1'}},
#  '0112': {'002': {'SD': '20020425', 'ED': '99991231', 'VFlg': '1'},
#   '003': {'SD': '20020425', 'ED': '99991231', 'VFlg': '1'},
#   '004': {'SD': '20020425', 'ED': '99991231', 'VFlg': '1'},
#   '006': {'SD': '20020425', 'ED': '99991231', 'VFlg': '1'},
#   '010': {'SD': '20030604', 'ED': '99991231', 'VFlg': '1'},
#   '012': {'SD': '20210311', 'ED': '99991231', 'VFlg': '1'},
#   '026': {'SD': '20020425', 'ED': '99991231', 'VFlg': '1'},
#   '050': {'SD': '20020425', 'ED': '99991231', 'VFlg': '1'},
#   '051': {'SD': '20020425', 'ED': '99991231', 'VFlg': '1'},
#   '995': {'SD': '20181201', 'ED': '99991231', 'VFlg': '1'},
#   '996': {'SD': '20020425', 'ED': '99991231', 'VFlg': '1'}},
#  '0113': {'001': {'SD': '20230401', 'ED': '99991231', 'VFlg': '1'},
#   '002': {'SD': '20230401', 'ED': '99991231', 'VFlg': '1'},
#   '003': {'SD': '20230401', 'ED': '99991231', 'VFlg': '1'},
#   '004': {'SD': '20230401', 'ED': '99991231', 'VFlg': '1'},
#   '006': {'SD': '20230401', 'ED': '99991231', 'VFlg': '1'},
#   '007': {'SD': '20230401', 'ED': '99991231', 'VFlg': '1'},
#   '008': {'SD': '20230401', 'ED': '99991231', 'VFlg': '1'},
#   '009': {'SD': '20230401', 'ED': '99991231', 'VFlg': '1'},
#   '010': {'SD': '20230401', 'ED': '99991231', 'VFlg': '1'},
#   '012': {'SD': '20230401', 'ED': '99991231', 'VFlg': '1'},
#   '026': {'SD': '20230401', 'ED': '99991231', 'VFlg': '1'},
#   '050': {'SD': '20230401', 'ED': '99991231', 'VFlg': '1'},
#   '051': {'SD': '20230401', 'ED': '99991231', 'VFlg': '1'},
#   '996': {'SD': '20230401', 'ED': '99991231', 'VFlg': '1'}},
#  '0201': {'002': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '003': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '004': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '005': {'SD': '19900401', 'ED': '99991231', 'VFlg': '1'},
#   '007': {'SD': '20000901', 'ED': '20020331', 'VFlg': '1'},
#   '008': {'SD': '20000901', 'ED': '20020331', 'VFlg': '1'},
#   '010': {'SD': '20020613', 'ED': '99991231', 'VFlg': '1'},
#   '012': {'SD': '20120313', 'ED': '99991231', 'VFlg': '1'},
#   '050': {'SD': '20030708', 'ED': '99991231', 'VFlg': '1'},
#   '051': {'SD': '20030708', 'ED': '99991231', 'VFlg': '1'},
#   '052': {'SD': '20000901', 'ED': '20020331', 'VFlg': '1'}},
#  '0202': {'001': {'SD': '19930401', 'ED': '20080605', 'VFlg': '1'},
#   '002': {'SD': '19930401', 'ED': '20120419', 'VFlg': '1'},
#   '003': {'SD': '19930401', 'ED': '20120419', 'VFlg': '1'},
#   '004': {'SD': '19930401', 'ED': '20120419', 'VFlg': '1'},
#   '005': {'SD': '19930401', 'ED': '19980331', 'VFlg': '1'},
#   '006': {'SD': '19930401', 'ED': '20120419', 'VFlg': '1'},
#   '010': {'SD': '19930401', 'ED': '20080605', 'VFlg': '1'},
#   '026': {'SD': '19930401', 'ED': '20120419', 'VFlg': '1'},
#   '050': {'SD': '19930401', 'ED': '20120419', 'VFlg': '1'},
#   '051': {'SD': '19930401', 'ED': '20120419', 'VFlg': '1'}},
#  '0203': {'001': {'SD': '19930420', 'ED': '20080417', 'VFlg': '1'},
#   '002': {'SD': '19930420', 'ED': '20160331', 'VFlg': '1'},
#   '003': {'SD': '19930420', 'ED': '20160331', 'VFlg': '1'},
#   '004': {'SD': '19930420', 'ED': '20160331', 'VFlg': '1'},
#   '005': {'SD': '19930420', 'ED': '20120426', 'VFlg': '1'},
#   '006': {'SD': '19930420', 'ED': '20160331', 'VFlg': '1'},
#   '010': {'SD': '19930420', 'ED': '20080417', 'VFlg': '1'},
#   '026': {'SD': '19930420', 'ED': '20160331', 'VFlg': '1'},
#   '050': {'SD': '19930420', 'ED': '20160331', 'VFlg': '1'},
#   '051': {'SD': '19930420', 'ED': '20160331', 'VFlg': '1'}},
#  '0204': {'005': {'SD': '20080601', 'ED': '99991231', 'VFlg': '1'},
#   '010': {'SD': '20080601', 'ED': '99991231', 'VFlg': '1'},
#   '012': {'SD': '20120313', 'ED': '99991231', 'VFlg': '1'},
#   '050': {'SD': '20080601', 'ED': '99991231', 'VFlg': '1'},
#   '051': {'SD': '20080601', 'ED': '99991231', 'VFlg': '1'}},
#  '0206': {'002': {'SD': '20140212', 'ED': '20150410', 'VFlg': '1'},
#   '003': {'SD': '20140212', 'ED': '20150410', 'VFlg': '1'},
#   '004': {'SD': '20140212', 'ED': '20150410', 'VFlg': '1'}},
#  '0208': {'002': {'SD': '20160322', 'ED': '20180612', 'VFlg': '1'},
#   '003': {'SD': '20160322', 'ED': '20180612', 'VFlg': '1'},
#   '004': {'SD': '20160322', 'ED': '20180612', 'VFlg': '1'},
#   '006': {'SD': '20160322', 'ED': '20180612', 'VFlg': '1'},
#   '026': {'SD': '20160322', 'ED': '20180612', 'VFlg': '1'},
#   '050': {'SD': '20160322', 'ED': '20180612', 'VFlg': '1'},
#   '051': {'SD': '20160322', 'ED': '20180612', 'VFlg': '1'},
#   '995': {'SD': '20160322', 'ED': '20180612', 'VFlg': '1'},
#   '996': {'SD': '20160322', 'ED': '20180612', 'VFlg': '1'}},
#  '0209': {'002': {'SD': '20180611', 'ED': '20191209', 'VFlg': '1'},
#   '003': {'SD': '20180611', 'ED': '20191209', 'VFlg': '1'},
#   '004': {'SD': '20180611', 'ED': '20191209', 'VFlg': '1'},
#   '006': {'SD': '20180611', 'ED': '20191209', 'VFlg': '1'},
#   '026': {'SD': '20180611', 'ED': '20191209', 'VFlg': '1'},
#   '050': {'SD': '20180611', 'ED': '20191209', 'VFlg': '1'},
#   '051': {'SD': '20180611', 'ED': '20191209', 'VFlg': '1'},
#   '995': {'SD': '20181201', 'ED': '20191209', 'VFlg': '1'},
#   '996': {'SD': '20180611', 'ED': '20191209', 'VFlg': '1'}},
#  '0300': {'002': {'SD': '20191218', 'ED': '20210315', 'VFlg': '1'},
#   '003': {'SD': '20191218', 'ED': '20210315', 'VFlg': '1'},
#   '004': {'SD': '20191218', 'ED': '20210315', 'VFlg': '1'},
#   '006': {'SD': '20191218', 'ED': '20210315', 'VFlg': '1'},
#   '026': {'SD': '20191218', 'ED': '20210315', 'VFlg': '1'},
#   '050': {'SD': '20191218', 'ED': '20210315', 'VFlg': '1'},
#   '051': {'SD': '20191218', 'ED': '20210315', 'VFlg': '1'},
#   '995': {'SD': '20191218', 'ED': '20210315', 'VFlg': '1'},
#   '996': {'SD': '20191218', 'ED': '20210315', 'VFlg': '1'}},
#  '0301': {'002': {'SD': '20210322', 'ED': '20211028', 'VFlg': '1'},
#   '003': {'SD': '20210322', 'ED': '20211028', 'VFlg': '1'},
#   '004': {'SD': '20210322', 'ED': '20211028', 'VFlg': '1'},
#   '006': {'SD': '20210322', 'ED': '20211028', 'VFlg': '1'},
#   '026': {'SD': '20210322', 'ED': '20211028', 'VFlg': '1'},
#   '050': {'SD': '20210322', 'ED': '20211028', 'VFlg': '1'},
#   '051': {'SD': '20210322', 'ED': '20211028', 'VFlg': '1'},
#   '995': {'SD': '20210322', 'ED': '20211028', 'VFlg': '1'},
#   '996': {'SD': '20210322', 'ED': '20211028', 'VFlg': '1'}},
#  '0302': {'002': {'SD': '20211101', 'ED': '20221122', 'VFlg': '1'},
#   '003': {'SD': '20211101', 'ED': '20221122', 'VFlg': '1'},
#   '004': {'SD': '20211101', 'ED': '20221122', 'VFlg': '1'},
#   '006': {'SD': '20211101', 'ED': '20221122', 'VFlg': '1'},
#   '010': {'SD': '20211101', 'ED': '20221122', 'VFlg': '1'},
#   '026': {'SD': '20211101', 'ED': '20221122', 'VFlg': '1'},
#   '050': {'SD': '20211101', 'ED': '20221122', 'VFlg': '1'},
#   '051': {'SD': '20211101', 'ED': '20221122', 'VFlg': '1'},
#   '995': {'SD': '20211101', 'ED': '20221122', 'VFlg': '1'},
#   '996': {'SD': '20211101', 'ED': '20221122', 'VFlg': '1'}},
#  '0303': {'002': {'SD': '20221129', 'ED': '20230927', 'VFlg': '1'},
#   '003': {'SD': '20221129', 'ED': '20230927', 'VFlg': '1'},
#   '004': {'SD': '20221129', 'ED': '20230927', 'VFlg': '1'},
#   '006': {'SD': '20221129', 'ED': '20230927', 'VFlg': '1'},
#   '010': {'SD': '20221129', 'ED': '20230927', 'VFlg': '1'},
#   '026': {'SD': '20221129', 'ED': '20230927', 'VFlg': '1'},
#   '050': {'SD': '20221129', 'ED': '20230927', 'VFlg': '1'},
#   '051': {'SD': '20221129', 'ED': '20230927', 'VFlg': '1'},
#   '995': {'SD': '20221129', 'ED': '20230927', 'VFlg': '1'},
#   '996': {'SD': '20221129', 'ED': '20230927', 'VFlg': '1'}},
#  '0304': {'002': {'SD': '20231107', 'ED': '99991231', 'VFlg': '1'},
#   '003': {'SD': '20231107', 'ED': '99991231', 'VFlg': '1'},
#   '004': {'SD': '20231107', 'ED': '99991231', 'VFlg': '1'},
#   '006': {'SD': '20231107', 'ED': '99991231', 'VFlg': '1'},
#   '010': {'SD': '20231107', 'ED': '99991231', 'VFlg': '1'},
#   '026': {'SD': '20231107', 'ED': '99991231', 'VFlg': '1'},
#   '050': {'SD': '20231107', 'ED': '99991231', 'VFlg': '1'},
#   '051': {'SD': '20231107', 'ED': '99991231', 'VFlg': '1'},
#   '995': {'SD': '20231107', 'ED': '99991231', 'VFlg': '1'},
#   '996': {'SD': '20231107', 'ED': '99991231', 'VFlg': '1'}}}

# %%
! wget  https://taiki.pref.yamanashi.jp/data/V502Item.json

with open("V502Item.json") as f:
    items = json.load(f)
items
# Out:
# --2024-08-08 13:26:57--  https://taiki.pref.yamanashi.jp/data/V502Item.json
# Resolving taiki.pref.yamanashi.jp (taiki.pref.yamanashi.jp)... 103.2.2.190
# Connecting to taiki.pref.yamanashi.jp (taiki.pref.yamanashi.jp)|103.2.2.190|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3287 (3.2K) [application/json]
# Saving to: ‘V502Item.json’
#
# V502Item.json       100%[===================>]   3.21K  --.-KB/s    in 0s
#
# 2024-08-08 13:26:57 (37.6 MB/s) - ‘V502Item.json’ saved [3287/3287]
# {'006': {'itemId': '006',
#   'itemName': '光化学オキシダント',
#   'simpleName': 'OX',
#   'iniVal': '0',
#   'scale': '0.001',
#   'unit': 'ppm',
#   'formatString': '%.3f',
#   'od': 5,
#   'ul': 180,
#   'll': 0,
#   'chartInterval': '10',
#   'itemDispCd': 6,
#   'refValHour': None,
#   'refValDay': None,
#   'graphColor': '000080'},
#  '001': {'itemId': '001',
#   'itemName': '二酸化硫黄',
#   'simpleName': 'SO2',
#   'iniVal': '0',
#   'scale': '0.001',
#   'unit': 'ppm',
#   'formatString': '%.3f',
#   'od': 10,
#   'ul': 25,
#   'll': 0,
#   'chartInterval': '5',
#   'itemDispCd': 1,
#   'refValHour': None,
#   'refValDay': None,
#   'graphColor': '000080'},
#  '002': {'itemId': '002',
#   'itemName': '一酸化窒素',
#   'simpleName': 'NO',
#   'iniVal': '0',
#   'scale': '0.001',
#   'unit': 'ppm',
#   'formatString': '%.3f',
#   'od': 20,
#   'ul': 250,
#   'll': 0,
#   'chartInterval': '10',
#   'itemDispCd': 2,
#   'refValHour': None,
#   'refValDay': None,
#   'graphColor': '0000ff'},
#  '003': {'itemId': '003',
#   'itemName': '二酸化窒素',
#   'simpleName': 'NO2',
#   'iniVal': '0',
#   'scale': '0.001',
#   'unit': 'ppm',
#   'formatString': '%.3f',
#   'od': 30,
#   'ul': 150,
#   'll': 0,
#   'chartInterval': '10',
#   'itemDispCd': 3,
#   'refValHour': None,
#   'refValDay': None,
#   'graphColor': '008000'},
#  '004': {'itemId': '004',
#   'itemName': '窒素酸化物',
#   'simpleName': 'NOX',
#   'iniVal': '0',
#   'scale': '0.001',
#   'unit': 'ppm',
#   'formatString': '%.3f',
#   'od': 40,
#   'ul': 300,
#   'll': 0,
#   'chartInterval': '25',
#   'itemDispCd': 4,
#   'refValHour': None,
#   'refValDay': None,
#   'graphColor': '008080'},
#  '005': {'itemId': '005',
#   'itemName': '一酸化炭素',
#   'simpleName': 'CO',
#   'iniVal': '0',
#   'scale': '0.1',
#   'unit': 'ppm',
#   'formatString': '%.1f',
#   'od': 50,
#   'ul': 50,
#   'll': 0,
#   'chartInterval': '10',
#   'itemDispCd': 5,
#   'refValHour': None,
#   'refValDay': None,
#   'graphColor': '00ff00'},
#  '008': {'itemId': '008',
#   'itemName': 'メタン',
#   'simpleName': 'CH4',
#   'iniVal': '0',
#   'scale': '0.01',
#   'unit': 'ppmC',
#   'formatString': '%.2f',
#   'od': 70,
#   'ul': 500,
#   'll': 0,
#   'chartInterval': '100',
#   'itemDispCd': 8,
#   'refValHour': None,
#   'refValDay': None,
#   'graphColor': '800000'},
#  '007': {'itemId': '007',
#   'itemName': '非メタン炭化水素',
#   'simpleName': 'NMHC',
#   'iniVal': '0',
#   'scale': '0.01',
#   'unit': 'ppmC',
#   'formatString': '%.2f',
#   'od': 80,
#   'ul': 500,
#   'll': 0,
#   'chartInterval': '100',
#   'itemDispCd': 7,
#   'refValHour': None,
#   'refValDay': None,
#   'graphColor': '800080'},
#  '009': {'itemId': '009',
#   'itemName': '全炭化水素',
#   'simpleName': 'THC',
#   'iniVal': '0',
#   'scale': '0.01',
#   'unit': 'ppmC',
#   'formatString': '%.2f',
#   'od': 90,
#   'ul': 1000,
#   'll': 0,
#   'chartInterval': '100',
#   'itemDispCd': 9,
#   'refValHour': None,
#   'refValDay': None,
#   'graphColor': '808000'},
#  '010': {'itemId': '010',
#   'itemName': '浮遊粒子状物質',
#   'simpleName': 'SPM',
#   'iniVal': '0',
#   'scale': '0.001',
#   'unit': 'mg/m3',
#   'formatString': '%.3f',
#   'od': 100,
#   'ul': 300,
#   'll': 0,
#   'chartInterval': '20',
#   'itemDispCd': 10,
#   'refValHour': None,
#   'refValDay': None,
#   'graphColor': 'ff0000'},
#  '012': {'itemId': '012',
#   'itemName': '微小粒子状物質',
#   'simpleName': 'PM2.5',
#   'iniVal': '0',
#   'scale': '1',
#   'unit': '&mu;g/m3',
#   'formatString': '%d',
#   'od': 110,
#   'ul': 150,
#   'll': -20,
#   'chartInterval': '10',
#   'itemDispCd': 33,
#   'refValHour': None,
#   'refValDay': None,
#   'graphColor': 'ff00ff'},
#  '050': {'itemId': '050',
#   'itemName': '風向',
#   'simpleName': 'WD',
#   'iniVal': '0',
#   'scale': '1',
#   'unit': '方位',
#   'formatString': '%d',
#   'od': 120,
#   'ul': 17,
#   'll': 0,
#   'chartInterval': '10',
#   'itemDispCd': 13,
#   'refValHour': None,
#   'refValDay': None,
#   'graphColor': 'ff99cc'},
#  '051': {'itemId': '051',
#   'itemName': '風速',
#   'simpleName': 'WS',
#   'iniVal': '0',
#   'scale': '0.1',
#   'unit': 'm/s',
#   'formatString': '%.1f',
#   'od': 130,
#   'ul': 150,
#   'll': 0,
#   'chartInterval': '10',
#   'itemDispCd': 14,
#   'refValHour': None,
#   'refValDay': None,
#   'graphColor': 'ffff00'}}

# %%
columns = set()
for scode, sinfo in table.items():
    columns |= set(sinfo.keys())
columns
# Out:
# {'001',
#  '002',
#  '003',
#  '004',
#  '005',
#  '006',
#  '007',
#  '008',
#  '009',
#  '010',
#  '012',
#  '026',
#  '050',
#  '051',
#  '995',
#  '996'}

# %%
icodes = sorted(list(columns))
icodes
# Out:
# ['001',
#  '002',
#  '003',
#  '004',
#  '005',
#  '006',
#  '007',
#  '008',
#  '009',
#  '010',
#  '012',
#  '026',
#  '050',
#  '051',
#  '995',
#  '996']

# %%
header = ["測定局", "区分"]
for icode in icodes:
    if icode in items:
        iinfo = items[icode]
        header.append(f'{iinfo["itemName"]}, {iinfo["unit"]}')
    else:
        header.append(icode)
header
# Out:
# ['測定局',
#  '区分',
#  '二酸化硫黄, ppm',
#  '一酸化窒素, ppm',
#  '二酸化窒素, ppm',
#  '窒素酸化物, ppm',
#  '一酸化炭素, ppm',
#  '光化学オキシダント, ppm',
#  '非メタン炭化水素, ppmC',
#  'メタン, ppmC',
#  '全炭化水素, ppmC',
#  '浮遊粒子状物質, mg/m3',
#  '微小粒子状物質, &mu;g/m3',
#  '026',
#  '風向, 方位',
#  '風速, m/s',
#  '995',
#  '996']

# %%
body = [header]
for scode, sinfo in table.items():
    if scode in stations:
        row = [stations[scode]["name"], stations[scode]["cate"]]
        for icode in icodes:
            if icode in sinfo:
                row.append(sinfo[icode])
            else:
                row.append("---")
    else:
        row = [scode]
    body.append(row)

body
# Out:
# [['測定局',
#   '区分',
#   '二酸化硫黄, ppm',
#   '一酸化窒素, ppm',
#   '二酸化窒素, ppm',
#   '窒素酸化物, ppm',
#   '一酸化炭素, ppm',
#   '光化学オキシダント, ppm',
#   '非メタン炭化水素, ppmC',
#   'メタン, ppmC',
#   '全炭化水素, ppmC',
#   '浮遊粒子状物質, mg/m3',
#   '微小粒子状物質, &mu;g/m3',
#   '026',
#   '風向, 方位',
#   '風速, m/s',
#   '995',
#   '996'],
#  ['大月',
#   '一般',
#   '0.001',
#   '0.000',
#   '0.003',
#   '0.003',
#   '---',
#   '0.062',
#   '0.04',
#   '1.98',
#   '2.02',
#   '0.023',
#   '20',
#   '62',
#   '2',
#   '3.8',
#   '308',
#   '0.043'],
#  ['上野原',
#   '一般',
#   '---',
#   '0.001',
#   '0.004',
#   '0.005',
#   '---',
#   '0.068',
#   '0.13',
#   '1.92',
#   '2.05',
#   '0.018',
#   '14',
#   '72',
#   '6',
#   '4.2',
#   '295',
#   '0.042'],
#  ['笛吹',
#   '一般',
#   '---',
#   '0.001',
#   '0.002',
#   '0.003',
#   '---',
#   '0.053',
#   '---',
#   '---',
#   '---',
#   '---',
#   '9',
#   '56',
#   '13',
#   '0.8',
#   '327',
#   '---'],
#  ['吉田',
#   '一般',
#   '0.001',
#   '0.001',
#   '0.005',
#   '0.006',
#   '---',
#   '0.056',
#   '---',
#   '---',
#   '---',
#   '0.028',
#   '17',
#   '57',
#   '2',
#   '2.9',
#   '292',
#   '0.043'],
#  ['南アルプス',
#   '一般',
#   '---',
#   '0.001',
#   '0.002',
#   '0.003',
#   '---',
#   '0.057',
#   '---',
#   '---',
#   '---',
#   '0.022',
#   '13',
#   '59',
#   '10',
#   '3.2',
#   '278',
#   '0.052'],
#  ['都留',
#   '一般',
#   '---',
#   '---',
#   '---',
#   '---',
#   '---',
#   '0.055',
#   '---',
#   '---',
#   '---',
#   '---',
#   '---',
#   '57',
#   '2',
#   '2.1',
#   '280',
#   '0.041'],
#  ['東山梨',
#   '一般',
#   '---',
#   '0.001',
#   '0.003',
#   '0.004',
#   '---',
#   '0.059',
#   '---',
#   '---',
#   '---',
#   '0.017',
#   '30',
#   '59',
#   '12',
#   '2.4',
#   '274',
#   '0.049'],
#  ['韮崎',
#   '一般',
#   '---',
#   '0.001',
#   '0.006',
#   '0.007',
#   '---',
#   '0.057',
#   '---',
#   '---',
#   '---',
#   '0.015',
#   '9',
#   '59',
#   '7',
#   '1.6',
#   '312',
#   '0.048'],
#  ['南部',
#   '一般',
#   '---',
#   '0.000',
#   '0.001',
#   '0.001',
#   '---',
#   '0.057',
#   '---',
#   '---',
#   '---',
#   '0.010',
#   '9',
#   '58',
#   '11',
#   '2.1',
#   '257',
#   '0.046'],
#  ['甲府穴切',
#   '一般',
#   '0.001',
#   '0.000',
#   '0.002',
#   '0.002',
#   '---',
#   '0.066',
#   '0.24',
#   '1.96',
#   '2.20',
#   '0.019',
#   '39',
#   '65',
#   '10',
#   '0.6',
#   '---',
#   '0.059'],
#  ['甲府市役所自排',
#   '自排',
#   '---',
#   '0.001',
#   '0.007',
#   '0.008',
#   '0.2',
#   '---',
#   '---',
#   '---',
#   '---',
#   '0.013',
#   '9',
#   '---',
#   '10',
#   '0.7',
#   '---',
#   '---'],
#  ['国母自排',
#   '自排',
#   '---',
#   '---',
#   '---',
#   '---',
#   '0.3',
#   '---',
#   '---',
#   '---',
#   '---',
#   '0.015',
#   '45',
#   '---',
#   '12',
#   '1.0',
#   '---',
#   '---'],
#  ['移動局_身延',
#   '一般',
#   '---',
#   '0.000',
#   '0.002',
#   '0.002',
#   '---',
#   '0.057',
#   '---',
#   '---',
#   '---',
#   '0.003',
#   '---',
#   '57',
#   '9',
#   '5.0',
#   '259',
#   '0.047']]

# %%
from IPython.display import HTML
from tabulate import tabulate

HTML(tabulate(body, tablefmt="html"))
# Out:
# <table>
# <tbody>
# <tr><td>測定局        </td><td>区分</td><td>二酸化硫黄, ppm</td><td>一酸化窒素, ppm</td><td>二酸化窒素, ppm</td><td>窒素酸化物, ppm</td><td>一酸化炭素, ppm</td><td>光化学オキシダント, ppm</td><td>非メタン炭化水素, ppmC</td><td>メタン, ppmC</td><td>全炭化水素, ppmC</td><td>浮遊粒子状物質, mg/m3</td><td>微小粒子状物質, &amp;mu;g/m3</td><td>026</td><td>風向, 方位</td><td>風速, m/s</td><td>995</td><td>996  </td></tr>
# <tr><td>大月          </td><td>一般</td><td>0.001          </td><td>0.000          </td><td>0.003          </td><td>0.003          </td><td>---            </td><td>0.062                  </td><td>0.04                  </td><td>1.98        </td><td>2.02            </td><td>0.023                </td><td>20                      </td><td>62 </td><td>2         </td><td>3.8      </td><td>308</td><td>0.043</td></tr>
# <tr><td>上野原        </td><td>一般</td><td>---            </td><td>0.001          </td><td>0.004          </td><td>0.005          </td><td>---            </td><td>0.068                  </td><td>0.13                  </td><td>1.92        </td><td>2.05            </td><td>0.018                </td><td>14                      </td><td>72 </td><td>6         </td><td>4.2      </td><td>295</td><td>0.042</td></tr>
# <tr><td>笛吹          </td><td>一般</td><td>---            </td><td>0.001          </td><td>0.002          </td><td>0.003          </td><td>---            </td><td>0.053                  </td><td>---                   </td><td>---         </td><td>---             </td><td>---                  </td><td>9                       </td><td>56 </td><td>13        </td><td>0.8      </td><td>327</td><td>---  </td></tr>
# <tr><td>吉田          </td><td>一般</td><td>0.001          </td><td>0.001          </td><td>0.005          </td><td>0.006          </td><td>---            </td><td>0.056                  </td><td>---                   </td><td>---         </td><td>---             </td><td>0.028                </td><td>17                      </td><td>57 </td><td>2         </td><td>2.9      </td><td>292</td><td>0.043</td></tr>
# <tr><td>南アルプス    </td><td>一般</td><td>---            </td><td>0.001          </td><td>0.002          </td><td>0.003          </td><td>---            </td><td>0.057                  </td><td>---                   </td><td>---         </td><td>---             </td><td>0.022                </td><td>13                      </td><td>59 </td><td>10        </td><td>3.2      </td><td>278</td><td>0.052</td></tr>
# <tr><td>都留          </td><td>一般</td><td>---            </td><td>---            </td><td>---            </td><td>---            </td><td>---            </td><td>0.055                  </td><td>---                   </td><td>---         </td><td>---             </td><td>---                  </td><td>---                     </td><td>57 </td><td>2         </td><td>2.1      </td><td>280</td><td>0.041</td></tr>
# <tr><td>東山梨        </td><td>一般</td><td>---            </td><td>0.001          </td><td>0.003          </td><td>0.004          </td><td>---            </td><td>0.059                  </td><td>---                   </td><td>---         </td><td>---             </td><td>0.017                </td><td>30                      </td><td>59 </td><td>12        </td><td>2.4      </td><td>274</td><td>0.049</td></tr>
# <tr><td>韮崎          </td><td>一般</td><td>---            </td><td>0.001          </td><td>0.006          </td><td>0.007          </td><td>---            </td><td>0.057                  </td><td>---                   </td><td>---         </td><td>---             </td><td>0.015                </td><td>9                       </td><td>59 </td><td>7         </td><td>1.6      </td><td>312</td><td>0.048</td></tr>
# <tr><td>南部          </td><td>一般</td><td>---            </td><td>0.000          </td><td>0.001          </td><td>0.001          </td><td>---            </td><td>0.057                  </td><td>---                   </td><td>---         </td><td>---             </td><td>0.010                </td><td>9                       </td><td>58 </td><td>11        </td><td>2.1      </td><td>257</td><td>0.046</td></tr>
# <tr><td>甲府穴切      </td><td>一般</td><td>0.001          </td><td>0.000          </td><td>0.002          </td><td>0.002          </td><td>---            </td><td>0.066                  </td><td>0.24                  </td><td>1.96        </td><td>2.20            </td><td>0.019                </td><td>39                      </td><td>65 </td><td>10        </td><td>0.6      </td><td>---</td><td>0.059</td></tr>
# <tr><td>甲府市役所自排</td><td>自排</td><td>---            </td><td>0.001          </td><td>0.007          </td><td>0.008          </td><td>0.2            </td><td>---                    </td><td>---                   </td><td>---         </td><td>---             </td><td>0.013                </td><td>9                       </td><td>---</td><td>10        </td><td>0.7      </td><td>---</td><td>---  </td></tr>
# <tr><td>国母自排      </td><td>自排</td><td>---            </td><td>---            </td><td>---            </td><td>---            </td><td>0.3            </td><td>---                    </td><td>---                   </td><td>---         </td><td>---             </td><td>0.015                </td><td>45                      </td><td>---</td><td>12        </td><td>1.0      </td><td>---</td><td>---  </td></tr>
# <tr><td>移動局_身延   </td><td>一般</td><td>---            </td><td>0.000          </td><td>0.002          </td><td>0.002          </td><td>---            </td><td>0.057                  </td><td>---                   </td><td>---         </td><td>---             </td><td>0.003                </td><td>---                     </td><td>57 </td><td>9         </td><td>5.0      </td><td>259</td><td>0.047</td></tr>
# </tbody>
# </table>

# %% [markdown]
# # パッケージ化
#
# 吉田は長野にもあるので、特定するための追加コードが必要。

# %%
from airpollution import yamanashi
import pandas as pd

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

print(yamanashi.retrieve("2024-08-08T10:00+09:00"))
# Out:
# 吉田
# 甲府穴切
# 移動局_身延
#           SO2   NO  NO2  NOX    OX  NMHC    CH4    THC   SPM  PM25    WD  \
# station
# 19206010  0.0  1.0  2.0  3.0  42.0   3.0  193.0  196.0  11.0  22.0   2.0
# 19441030  NaN  1.0  3.0  4.0  31.0  11.0  191.0  202.0  11.0  12.0   6.0
# 19321030  NaN  NaN  NaN  NaN   NaN   NaN    NaN    NaN   NaN   NaN  15.0
# 吉田        0.0  1.0  4.0  5.0  40.0   NaN    NaN    NaN  19.0  10.0   2.0
# 19390030  NaN  1.0  3.0  4.0  51.0   NaN    NaN    NaN  11.0   5.0   3.0
# 19204010  NaN  NaN  NaN  NaN  43.0   NaN    NaN    NaN   NaN   NaN   3.0
# 19205020  NaN  1.0  4.0  5.0  38.0   NaN    NaN    NaN  12.0  22.0   9.0
# 19207030  NaN  0.0  5.0  5.0  47.0   NaN    NaN    NaN   8.0   3.0   6.0
# 19366010  NaN  1.0  2.0  3.0  39.0   NaN    NaN    NaN  10.0   7.0  17.0
# 甲府穴切      1.0  1.0  4.0  5.0  53.0  18.0  198.0  216.0  17.0  28.0  12.0
# 19201011  NaN  1.0  7.0  8.0   NaN   NaN    NaN    NaN   8.0  27.0   4.0
# 19201510  NaN  NaN  NaN  NaN   NaN   NaN    NaN    NaN  10.0  45.0   NaN
# 移動局_身延    NaN  0.0  3.0  3.0  42.0   NaN    NaN    NaN   0.0   NaN   2.0
#
#             WS   CO
# station
# 19206010  29.0  NaN
# 19441030  24.0  NaN
# 19321030   9.0  NaN
# 吉田        31.0  NaN
# 19390030   8.0  NaN
# 19204010  16.0  NaN
# 19205020  12.0  NaN
# 19207030  11.0  NaN
# 19366010   3.0  NaN
# 甲府穴切      10.0  NaN
# 19201011  14.0  2.0
# 19201510   NaN  2.0
# 移動局_身延    28.0  NaN
