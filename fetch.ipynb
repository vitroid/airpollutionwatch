# %% [markdown]
# 全県まとめて。

# %%
# %%time
from airpollution import kanagawa, shizuoka, tokyo, chiba, yamanashi
import pandas as pd

pd.set_option("display.max_rows", None)
pd.set_option("display.max_columns", None)

dt = "2024-08-07T11:00+09:00"
print(kanagawa.retrieve(dt))
print(chiba.retrieve(dt))
print(tokyo.retrieve(dt))
print(yamanashi.retrieve(dt))
print(shizuoka.retrieve(dt))
# Out:
# 逗子市逗子
# 西丹沢犬越路
# 移動局山北町
# 国設川崎（田島）
# 中原区地域みまもり支援センター
# 高津区生活文化会館
# 多摩区登戸小学校
# 麻生区弘法松公園
# 川崎区池上新田公園前
# 川崎区日進町
# 幸区遠藤町交差点
# 高津区二子
# 多摩区本村橋
# 麻生区柿生
# 川崎区富士見公園
# 川崎市役所第３庁舎
# 横須賀市追浜行政センター
# 横須賀市久里浜行政センター
# 横須賀市西行政センター
# 横須賀市小川町交差点
# 横須賀市池上ｺﾐｭﾆﾃｨｾﾝﾀｰ
# 相模原市相模台
# 相模原市橋本
# 相模原市田名
# 相模原市津久井
# 相模原市上溝
# 相模原市古淵
# 藤沢市湘南台小学校
# 藤沢市御所見小学校
# 藤沢市明治市民センター
# 平塚市大野公民館
# 平塚市神田小学校
# 平塚市旭小学校
# 平塚市花水小学校
# 平塚市松原歩道橋
# 705
# 708
# 709
# 710
# 712
# 713
# 714
# 715
# 717
# 718
# 719
# 720
# 721
# 724
# 725
# 726
# 727
# 728
# 730
# 731
# 732
# 733
# 734
# 735
# 736
# 737
# 738
# 739
# 740
# 741
# 742
# 743
# 744
# 745
# 746
# 747
# 754
# 762
# 804
# 805
# 806
# 807
# 811
# 812
# 814
# 818
# 831
# 832
# 833
# 834
# 851
# 852
# 853
# 855
# 856
# 857
# 858
# 860
# 861
# 862
# 863
# 864
# 865
# 866
# 867
# 868
# 869
# 870
# 871
# 872
# 873
# 874
# 876
# 877
# 878
# 879
# 880
# 881
# 882
# 883
# 884
# 885
# 886
# 887
# 889
# 890
# 891
# 893
# 896
# 898
# 899
# 900
# 901
# 902
# 903
# 904
# 906
# ...

# %% [markdown]
# 新しい時刻で 3 秒弱、キャッシュされていれば 1 秒以下でデータをもってこられる。
